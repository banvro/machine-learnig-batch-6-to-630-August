# %%
import pandas as pd
import numpy as np

# %%
x = 6 * np.random.rand(200, 1) - 3

# %%
y = 0.8 * x ** 2 + 0.9 *x + 2 + np.random.randn(200, 1)


# y = 0.8x^2 +0.9x + 2

# %%
x
# Out:
# array([[ 2.14028446],
#        [-0.57564461],
#        [ 1.74959313],
#        [ 2.72804237],
#        [-1.62637654],
#        [-2.74525945],
#        [ 1.18004145],
#        [-2.69060534],
#        [-2.98011215],
#        [ 2.65363891],
#        [ 1.12674177],
#        [ 2.99678953],
#        [-1.66566319],
#        [-0.56186334],
#        [ 1.92982319],
#        [ 1.06777144],
#        [ 2.25376065],
#        [ 0.19319965],
#        [-0.58424094],
#        [-2.0099282 ],
#        [ 2.49508798],
#        [-2.57949374],
#        [-0.29555659],
#        [ 2.04336002],
#        [ 1.24355837],
#        [ 0.48662386],
#        [ 1.57981124],
#        [-0.27906788],
#        [ 0.97366887],
#        [ 2.01952998],
#        [ 0.70239792],
#        [-1.95167172],
#        [ 0.96167855],
#        [ 2.70571928],
#        [ 1.97344876],
#        [-2.47589308],
#        [ 0.44958704],
#        [-0.9969952 ],
#        [-1.78104151],
#        [-2.26506242],
#        [-2.59976984],
# ...

# %%
y
# Out:
# array([[ 8.08794478],
#        [ 3.03779875],
#        [ 5.35492261],
#        [11.05650263],
#        [ 2.57144244],
#        [ 4.75404074],
#        [ 4.7832121 ],
#        [ 5.83588853],
#        [ 7.27853233],
#        [ 9.67273713],
#        [ 4.77450603],
#        [10.59016415],
#        [ 2.11744287],
#        [ 1.90211789],
#        [ 7.42623481],
#        [ 4.35456144],
#        [ 7.59877672],
#        [ 1.50376484],
#        [ 2.15857039],
#        [ 3.17841748],
#        [ 9.41623763],
#        [ 3.29907529],
#        [ 0.81072113],
#        [ 8.7108926 ],
#        [ 3.72441857],
#        [ 3.01088449],
#        [ 5.0723206 ],
#        [ 1.53716826],
#        [ 3.57028266],
#        [ 6.59831143],
#        [ 3.4233513 ],
#        [ 3.86364677],
#        [ 2.56319007],
#        [10.33078287],
#        [ 6.79771291],
#        [ 5.13817248],
#        [ 1.38783681],
#        [ 1.08438891],
#        [ 2.79371981],
#        [ 3.3087249 ],
#        [ 4.18241164],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
y
# Out:
# array([[ 8.08794478],
#        [ 3.03779875],
#        [ 5.35492261],
#        [11.05650263],
#        [ 2.57144244],
#        [ 4.75404074],
#        [ 4.7832121 ],
#        [ 5.83588853],
#        [ 7.27853233],
#        [ 9.67273713],
#        [ 4.77450603],
#        [10.59016415],
#        [ 2.11744287],
#        [ 1.90211789],
#        [ 7.42623481],
#        [ 4.35456144],
#        [ 7.59877672],
#        [ 1.50376484],
#        [ 2.15857039],
#        [ 3.17841748],
#        [ 9.41623763],
#        [ 3.29907529],
#        [ 0.81072113],
#        [ 8.7108926 ],
#        [ 3.72441857],
#        [ 3.01088449],
#        [ 5.0723206 ],
#        [ 1.53716826],
#        [ 3.57028266],
#        [ 6.59831143],
#        [ 3.4233513 ],
#        [ 3.86364677],
#        [ 2.56319007],
#        [10.33078287],
#        [ 6.79771291],
#        [ 5.13817248],
#        [ 1.38783681],
#        [ 1.08438891],
#        [ 2.79371981],
#        [ 3.3087249 ],
#        [ 4.18241164],
# ...

# %%
x_train
# Out:
# array([[-0.71762966],
#        [ 2.49508798],
#        [-2.8234954 ],
#        [ 1.88964788],
#        [ 0.9398146 ],
#        [ 1.57981124],
#        [-0.27906788],
#        [ 2.18896495],
#        [ 1.60458199],
#        [ 1.38266247],
#        [-0.58708314],
#        [ 0.1710453 ],
#        [ 2.60164775],
#        [ 1.06777144],
#        [ 0.41875203],
#        [ 2.14313994],
#        [ 0.95304771],
#        [ 2.70571928],
#        [-2.62345678],
#        [-1.78104151],
#        [ 2.40836435],
#        [-2.26792435],
#        [ 0.26302331],
#        [ 2.47996361],
#        [ 2.04336002],
#        [-0.29555659],
#        [-2.19750448],
#        [ 0.99372387],
#        [ 0.65784986],
#        [-2.0099282 ],
#        [ 0.01952686],
#        [-2.58635143],
#        [ 2.01952998],
#        [ 0.99175024],
#        [-2.48908016],
#        [ 1.74959313],
#        [-1.59773636],
#        [-2.25502062],
#        [-0.18363595],
#        [ 1.67587899],
#        [ 1.24355837],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
obj = LinearRegression()

# %%
obj.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_pread = obj.predict(x_test)

# %%
y_pread
# Out:
# array([[4.66555094],
#        [3.74510766],
#        [4.08488464],
#        [6.89719207],
#        [1.59216752],
#        [2.63900626],
#        [1.8513895 ],
#        [4.79138527],
#        [3.73741058],
#        [2.42461524],
#        [4.48215307],
#        [3.10218039],
#        [3.81120271],
#        [5.82990898],
#        [6.66888355],
#        [3.29795924],
#        [3.7216884 ],
#        [5.12161397],
#        [3.61982447],
#        [3.04359859],
#        [1.6732917 ],
#        [5.31713428],
#        [1.77824077],
#        [3.34501146],
#        [1.75561893],
#        [6.2573316 ],
#        [4.88945626],
#        [4.90740315],
#        [2.44290696],
#        [2.04364107],
#        [1.93272285],
#        [5.32926306],
#        [6.20582074],
#        [4.66309151],
#        [5.95808224],
#        [5.75275787],
#        [2.35155914],
#        [4.38490876],
#        [5.59349774],
#        [6.03685726]])

# %%
r2_score(y_test, y_pread)
# Out:
# 0.07194460873379871

# %%
plt.plot(x_train, obj.predict(x_train), color="red")
plt.scatter(x, y)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
oj = PolynomialFeatures(degree = 2)

# %%
x_train
# Out:
# array([[-0.71762966],
#        [ 2.49508798],
#        [-2.8234954 ],
#        [ 1.88964788],
#        [ 0.9398146 ],
#        [ 1.57981124],
#        [-0.27906788],
#        [ 2.18896495],
#        [ 1.60458199],
#        [ 1.38266247],
#        [-0.58708314],
#        [ 0.1710453 ],
#        [ 2.60164775],
#        [ 1.06777144],
#        [ 0.41875203],
#        [ 2.14313994],
#        [ 0.95304771],
#        [ 2.70571928],
#        [-2.62345678],
#        [-1.78104151],
#        [ 2.40836435],
#        [-2.26792435],
#        [ 0.26302331],
#        [ 2.47996361],
#        [ 2.04336002],
#        [-0.29555659],
#        [-2.19750448],
#        [ 0.99372387],
#        [ 0.65784986],
#        [-2.0099282 ],
#        [ 0.01952686],
#        [-2.58635143],
#        [ 2.01952998],
#        [ 0.99175024],
#        [-2.48908016],
#        [ 1.74959313],
#        [-1.59773636],
#        [-2.25502062],
#        [-0.18363595],
#        [ 1.67587899],
#        [ 1.24355837],
# ...

# %%
x_train_trnform = oj.fit_transform(x_train)

# %%
x_test_tranform = oj.transform(x_test)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train_trnform, y_train)
# Out:
# LinearRegression()

# %%
y_pre = lr.predict(x_test_tranform)

# %%
r2_score(y_test, y_pre)
# Out:
# 0.8873940002756853

# %%
x_train_trnform
# Out:
# array([[ 1.00000000e+00, -7.17629658e-01,  5.14992326e-01],
#        [ 1.00000000e+00,  2.49508798e+00,  6.22546405e+00],
#        [ 1.00000000e+00, -2.82349540e+00,  7.97212627e+00],
#        [ 1.00000000e+00,  1.88964788e+00,  3.57076910e+00],
#        [ 1.00000000e+00,  9.39814598e-01,  8.83251479e-01],
#        [ 1.00000000e+00,  1.57981124e+00,  2.49580356e+00],
#        [ 1.00000000e+00, -2.79067883e-01,  7.78788832e-02],
#        [ 1.00000000e+00,  2.18896495e+00,  4.79156756e+00],
#        [ 1.00000000e+00,  1.60458199e+00,  2.57468337e+00],
#        [ 1.00000000e+00,  1.38266247e+00,  1.91175550e+00],
#        [ 1.00000000e+00, -5.87083143e-01,  3.44666616e-01],
#        [ 1.00000000e+00,  1.71045301e-01,  2.92564949e-02],
#        [ 1.00000000e+00,  2.60164775e+00,  6.76857104e+00],
#        [ 1.00000000e+00,  1.06777144e+00,  1.14013584e+00],
#        [ 1.00000000e+00,  4.18752029e-01,  1.75353262e-01],
#        [ 1.00000000e+00,  2.14313994e+00,  4.59304878e+00],
# ...

# %%
y = lr.intercept_

# %%
y
# Out:
# array([1.8988864])

# %%
x = lr.coef_
x
# Out:
# array([[0.        , 0.90924894, 0.80808537]])

# %%
# y = B0 + B1x0 + B2x1 + B3x2
y = y + 0. * 1. + 0.90924894 * 0.4523338 + 0.80808537 * 0.20460587

y
# Out:
# array([2.47550944])

# %%
x_test_tranform
# Out:
# array([[ 1.        ,  0.4523338 ,  0.20460587],
#        [ 1.        , -0.57564461,  0.33136672],
#        [ 1.        , -0.19617158,  0.03848329],
#        [ 1.        ,  2.94469695,  8.67124012],
#        [ 1.        , -2.98011215,  8.88106846],
#        [ 1.        , -1.81097153,  3.2796179 ],
#        [ 1.        , -2.69060534,  7.23935711],
#        [ 1.        ,  0.59286932,  0.35149403],
#        [ 1.        , -0.58424094,  0.34133748],
#        [ 1.        , -2.0504098 ,  4.20418037],
#        [ 1.        ,  0.24750961,  0.06126101],
#        [ 1.        , -1.29368491,  1.67362063],
#        [ 1.        , -0.5018277 ,  0.25183104],
#        [ 1.        ,  1.75272347,  3.07203956],
#        [ 1.        ,  2.68971521,  7.23456792],
#        [ 1.        , -1.07503326,  1.1556965 ],
#        [ 1.        , -0.60179993,  0.36216316],
#        [ 1.        ,  0.96167855,  0.92482563],
#        [ 1.        , -0.7155646 ,  0.5120327 ],
#        [ 1.        , -1.3591108 ,  1.84718216],
# ...

# %%
y_test
# Out:
# array([[ 2.58087707],
#        [ 3.03779875],
#        [ 0.46754975],
#        [12.01367478],
#        [ 7.27853233],
#        [ 3.04817444],
#        [ 5.83588853],
#        [ 1.73000309],
#        [ 2.15857039],
#        [ 4.51022688],
#        [ 1.17708131],
#        [ 1.52705017],
#        [ 1.21038037],
#        [ 7.51153238],
#        [11.93193181],
#        [-0.04070017],
#        [-0.12135858],
#        [ 2.56319007],
#        [ 3.80651973],
#        [ 1.58715113],
#        [ 6.43936582],
#        [ 4.7832121 ],
#        [ 5.34382102],
#        [ 1.48259124],
#        [ 6.34870037],
#        [ 7.64776658],
#        [ 3.4233513 ],
#        [ 2.69175483],
#        [ 4.86630931],
#        [ 5.13817248],
#        [ 4.18241164],
#        [ 5.61090565],
#        [ 8.87140805],
#        [ 1.38783681],
#        [ 6.4597445 ],
#        [ 4.99337967],
#        [ 3.0300773 ],
#        [ 2.16904915],
#        [ 5.55771096],
#        [ 7.16845759]])
